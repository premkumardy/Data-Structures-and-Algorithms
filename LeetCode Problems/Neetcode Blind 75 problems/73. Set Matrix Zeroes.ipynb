# %% [markdown]
# 73. Set Matrix Zeroes
#
# Given an m x n integer matrix matrix, if an element is 0, set its entire row and column to 0's.
#
# You must do it in place.
#
#
#
# Example 1:
#
# ![image.png](attachment:image.png)
#
#
# Input: matrix = [[1,1,1],[1,0,1],[1,1,1]]
# Output: [[1,0,1],[0,0,0],[1,0,1]]
# Example 2:
#
# ![image-2.png](attachment:image-2.png)
#
# Input: matrix = [[0,1,2,0],[3,4,5,2],[1,3,1,5]]
# Output: [[0,0,0,0],[0,4,5,0],[0,3,1,0]]
#
#
# Constraints:
#
# m == matrix.length
# n == matrix[0].length
# 1 <= m, n <= 200
# -231 <= matrix[i][j] <= 231 - 1

# %%
#O(m*n) TC, O(1) SC 
class Solution:
    def setZeroes(self, matrix):
        """
        Do not return anything, modify matrix in-place instead.
        """
        rows,cols = len(matrix),len(matrix[0])
        rowZero = True

        for r in range(rows):
            for c in range(cols):
                if not matrix[r][c]:
                    matrix[0][c] = 0
                    if not r: # if its matrix[0][0] then set rowZero to 0
                        rowZero = 0 
                        continue
                    matrix[r][0] = 0 # if r is > 0 then set the left most border for marking

        for r in range(1,rows):
            for c in range(1,cols):
                if not matrix[0][c] or not matrix[r][0]:
                    matrix[r][c] = 0

        if not matrix[0][0]:
            for r in range(1,rows):
                matrix[r][0] = 0

        if not rowZero:
            for c in range(cols):
                matrix[0][c] = 0

# %%
# O((m*n)*(m+n)) here(m+n) comes from 3rd and 4th for loop iteratiion  TC, O(m*n) SC
class Solution: 
    def setZeroes(self, matrix):
        """
        Do not return anything, modify matrix in-place instead.
        """


        def printMatrix(matrix):
            for elmt in matrix:
                print(elmt)

            print()

        rows,cols = len(matrix),len(matrix[0])
        dummy = [[matrix[r][c] for c in range(cols)] for r in range(rows)]

        for i in range(rows):
            for j in range(cols):
                if matrix[i][j] == 0:
                    for c in range(cols):
                        dummy[i][c] = 0
                    for r in range(rows):
                        dummy[r][j] = 0
        
        printMatrix(matrix)
        printMatrix(dummy)

                    

        


matrix = [[0,1,2,0],[3,4,5,2],[1,3,1,5]]
Solution().setZeroes(matrix)
# Out:
# [0, 1, 2, 0]
# [3, 4, 5, 2]
# [1, 3, 1, 5]
#
# [0, 0, 0, 0]
# [0, 4, 5, 0]
# [0, 3, 1, 0]

# %% [markdown]
# 154. Find Minimum in Rotated Sorted Array II
#
# Suppose an array of length n sorted in ascending order is rotated between 1 and n times. For example, the array nums = [0,1,4,4,5,6,7] might become:
#
# [4,5,6,7,0,1,4] if it was rotated 4 times.
# [0,1,4,4,5,6,7] if it was rotated 7 times.
# Notice that rotating an array [a[0], a[1], a[2], ..., a[n-1]] 1 time results in the array [a[n-1], a[0], a[1], a[2], ..., a[n-2]].
#
# Given the sorted rotated array nums that may contain duplicates, return the minimum element of this array.
#
# You must decrease the overall operation steps as much as possible.
#
#
#
# Example 1:
#
# Input: nums = [1,3,5]
# Output: 1
# Example 2:
#
# Input: nums = [2,2,2,0,1]
# Output: 0
#
#
# Constraints:
#
# n == nums.length
# 1 <= n <= 5000
# -5000 <= nums[i] <= 5000
# nums is sorted and rotated between 1 and n times.

# %%
class Solution(object):
    def findMin(self, nums):
        """
        Observation: we are given a sorted array where left segment might be rotated
        if left most element is less than right most element, we can say that its not rotated and its sorted
        nums[0] <= nums[-1] -> nums is sorted and unrotated, return nums[0]
        
        when we go in to loop we check if nums[l] < nums[r] we are sure that we are not into the second right segment of of sorted array,
        and so if 

        when we take a mid point and if is greater than left it means that we are in the left part of roatated sigment and we can start looking right part,
        but before shifting focus to right segment, what if mid is the smallest ? , use greedy and update res variable on each iteration.
        when looop break, we would have updated res with min value.

        if nums[m] >= nums[l] l = m+1, start looking in right part
        if nums[m] < nums[r]  r = m-1, start looking in left part
        if nums[m] == target, r = r-1, this  is a tricky part, since we will be having duplicates, we need to lookout and reduce each repeated value and find - 
        the smallest.
        
        """

        l,r = 0, len(nums)-1
        if nums[l] < nums[r]:
            return nums[0]
    
        while l<r:
            if nums[l] < nums[r]:
                return nums[l]

            m = (l+r)//2

            if nums[m] > nums[r]:
                l = m+1
            elif nums[m] < nums[r]:
                r = m-1
            else:
                 r -= 1
        return nums[l]

Solution().findMin([10,1,10,10,10,10])
# Out:
# 10

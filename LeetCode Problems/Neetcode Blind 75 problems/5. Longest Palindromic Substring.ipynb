# %%
5. Longest Palindromic Substring

Given a string s, return the longest palindromic substring in s.

 

Example 1:

Input: s = "babad"
Output: "bab"
Explanation: "aba" is also a valid answer.
Example 2:

Input: s = "cbbd"
Output: "bb"
 

Constraints:

1 <= s.length <= 1000
s consist of only digits and English letters.
# Out:
#   Cell In[1], line 1
#     5. Longest Palindromic Substring
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: str
        """
        res = []
        resLen = 0
        
        def checkPalindrome(l,r):
            nonlocal resLen
            nonlocal res
            while l<=r and l >= 0 and r <len(s) and s[l] == s[r]:
                if (r-l+1) > resLen:
                    resLen = r-l+1
                    res = s[l:r+1]
                l-=1
                r+=1

        for i in range(len(s)):
            checkPalindrome(i,i)
            checkPalindrome(i,i+1)
    
        return res

Solution().longestPalindrome("A")
# Out:
# 'A'

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
"""
the requirement is to return longest palindromic sub string
we can use odd and even check method to calculate palindrome

instead of closing in from from left and right, we will be closing out from current l and r
while doing so, we will ensure current l,r is a palindrome and l and r are withing arr limit

we will perofrm odd palindrome check where l,r = i,i, spreading out from a single point
growing in 1,3,5,7...

we will perofrm even palindrome check where l,r = i,i+1 spreading out from a i,i+1 point
growing in 2,4,6,8,...

we will do greedy update to res by comparing resLen and updating both

return res


"""
# Out:
# '\nthe requirement is to return longest palindromic sub string\nwe can use odd and even check method to calculate palindrome\n\ninstead of closing in from from left and right, we will be closing out from current l and r\nwhile doing so, we will ensure current l,r is a palindrome and l and r are withing arr limit\n\nwe will perofrm odd palindrome check where l,r = i,i, spreading out from a single point\ngrowing in 1,3,5,7...\n\nwe will perofrm even palindrome check where l,r = i,i+1 spreading out from a i,i+1 point\ngrowing in 2,4,6,8,...\n\nwe will do greedy update to res by comparing resLen and updating both\n\nreturn res\n\n\n'

# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: str
        """
        
        res = []
        resLen = 0

        def checkPalindrome(l,r):
            nonlocal resLen #to access non local reference
            nonlocal res

            while l >= 0 and r < len(s) and s[l] == s[r]:
                if r-l+1 > resLen:
                    resLen = r-l+1
                    res = s[l:r+1]
                l-=1
                r+=1
        
        for i in range(len(s)):
            checkPalindrome(i,i)
            checkPalindrome(i,i+1)
        return res

Solution().longestPalindrome("ACC")
# Out:
# 'CC'

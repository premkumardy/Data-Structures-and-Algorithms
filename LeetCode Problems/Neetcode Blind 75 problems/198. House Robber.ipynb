# %% [markdown]
# You are a professional robber planning to rob houses along a street. Each house has a certain amount of money stashed, the only constraint stopping you from robbing each of them is that adjacent houses have security systems connected and it will automatically contact the police if two adjacent houses were broken into on the same night.
#
# Given an integer array nums representing the amount of money of each house, return the maximum amount of money you can rob tonight without alerting the police.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,1]
# Output: 4
# Explanation: Rob house 1 (money = 1) and then rob house 3 (money = 3).
# Total amount you can rob = 1 + 3 = 4.
# Example 2:
#
# Input: nums = [2,7,9,3,1]
# Output: 12
# Explanation: Rob house 1 (money = 2), rob house 3 (money = 9) and rob house 5 (money = 1).
# Total amount you can rob = 2 + 9 + 1 = 12.
#
#
# Constraints:
#
# 1 <= nums.length <= 100
# class Solution:
#     def rob(self, nums: List[int]) -> int:
#
# 0 <= nums[i] <= 400

# %%
class Solution:
    def rob(self, nums):
        if not nums:
            return 0
        for i in range(2,len(nums)):
            if i == 1: 
                nums[i] = max(nums[i],nums[i-1])
                continue
            nums[i] = max(nums[i]+nums[i-2],nums[i-1])
        return nums[-1]


nums = [2,1]
Solution().rob(nums)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"""

skip the current loot and carray the prev loot if current loot is lesser 


The intuition here is we will check at each indx if its ideal to steak the current ind'x value by checking if adding value previous 
to the left adjacent house, if (current house loot(nums[i]) + prev house of adjacent (nums[i-2])) < adjacent house (nums[i-1]), then
its ideal to have the maxmuimum loot out of the comparision

since we are using 2 pointer to store the n-i and n-2 the indx's loot, once we calculate the maximum loot at current position we will neglet the 
i-2 's postion by swapping values

rob1 will store rob2's value while shifting and represent i-2's loot 
and rob2 will store the current position's maxmum loot 
rob1,rob2 = rob2,max(nums[i]+rob1,rob2)

"""
class Solution:
    def rob(self, nums):

        rob1 = 0
        rob2 = 0
        for i in range(len(nums)):

            rob1,rob2 = rob2,max(nums[i]+rob1,rob2)
            
        return rob2


nums = [1,9,1,1,9,1]
Solution().rob(nums)
# Out:
# 18

# %%
# This is not greedy enough to skip the skip the next current elemen tto retain the maximum profit
nums = [1,9,1,1,9,1]


odd_count = 0
even_count = 0
for i in range(len(nums)):
    if i & 1:
        odd_count+= nums[i]
    else:
        even_count += nums[i]

max(odd_count,even_count)
# Out:
# 11

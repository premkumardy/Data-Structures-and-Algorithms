# %% [markdown]
# 15. 3Sum
#
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.
#
# Notice that the solution set must not contain duplicate triplets.
#
#
#
# Example 1:
#
# Input: nums = [-1,0,1,2,-1,-4]
# Output: [[-1,-1,2],[-1,0,1]]
# Explanation:
# nums[0] + nums[1] + nums[2] = (-1) + 0 + 1 = 0.
# nums[1] + nums[2] + nums[4] = 0 + 1 + (-1) = 0.
# nums[0] + nums[3] + nums[4] = (-1) + 2 + (-1) = 0.
# The distinct triplets are [-1,0,1] and [-1,-1,2].
# Notice that the order of the output and the order of the triplets does not matter.
# Example 2:
#
# Input: nums = [0,1,1]
# Output: []
# Explanation: The only possible triplet does not sum up to 0.
# Example 3:
#
# Input: nums = [0,0,0]
# Output: [[0,0,0]]
# Explanation: The only possible triplet sums up to 0.
#
#
# Constraints:
#
# 3 <= nums.length <= 3000
# -105 <= nums[i] <= 105

# %%
#brute force
class Solution(object):
    def threeSum(self, nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """

        ans = set()
        nums.sort()
        for i in range(len(nums)):
            for j in range(i+1,len(nums)):
                for k in range(j+1,len(nums)):
                    if (i!= j and j != k and k!= i) and (nums[i]+nums[j]+nums[k]) == 0:
                        ans.add((nums[i],nums[j],nums[k]))
        return [list(i) for i in ans]

Solution().threeSum([-1,0,1,2,-1,-4])
# Out:
# [[-1, 0, 1], [-1, -1, 2]]

# %%
class Solution(object):
    def threeSum(self, nums):
        """
        here we need to have a visit back LC 154,153

        we will initially sort the array,
        Observatiions:- 
        we need to be gegining with a value <= 0 to have a total sum of 0 eg [0,0,0] is zero, [-6,3,3] sums to 0, [1,2,3] first value begine with positve
        so we can skip it

        [-1,-1,0,1] we also will be ignoring same permutation, here we will be having ans as [-1,0,1] ans [-1,0,1], so when nums[i] == nums[i-1], we skip

        we will be doing a two pointer search for each i to calcualte nums[i] + nums[l] + nums[r]

        nums[i] + nums[l] + nums[r] = 0, we append res and move on find next possiblities
        if nums[i] + nums[l] + nums[r] > 0, we will decrement r -= 1, so on next iteration r will point a lesser value in nums
        if nums[i] + nums[l] + nums[r] < 0, we will increment l += 1, so on next iteration l will point a greater value in nums
        nums[i] + nums[l] + nums[r] = 0, we append res and move on find next possiblities by incremting l += 1, r += 1
        also we will skip duplicate values by running a while loop


        
        

        """
        res = []
        nums.sort()
        for indx,n in enumerate(nums):
            if n > 0:
                break
            if indx and n == nums[indx-1]:
                continue
            
            l,r = indx+1, len(nums)-1
            
            while l < r:
                t = n + nums[l] + nums[r]
                if t > 0:
                    l += 1
                elif t < 0:
                    r -= 1
                else:
                    res.append([n,nums[l],nums[r]])
                    l += 1
                    r -= 1
                    while l < r and nums[l] == nums[l-1]: #if l is not going out of the limit and check if current nums[l] is duplicate of previous
                        l += 1
                    #reason for continuewing the wo pointer search is that remaing possible values will be for sure within l and r
                    #coz we will be increating l indx and it is going to point a greater value in each increment
                    #and we for sure not going to check value behind in r indx, coz even for a lesser nums[l] we might have made r decremt to point at lower value
                    #so we will be incremrnting l and decrementing r, so we are continueing the two pointer search
                    
        return res

Solution().threeSum([-1,0,1,2,-1,-4])
# Out:
# [[0, 0, 0]]

# %%
class Solution(object):
    def threeSum(self, nums):

        res = []
        nums.sort()
        for indx,n in enumerate(nums):
            if n > 0:
                break
            if indx and n == nums[indx-1]:
                continue
            
            l,r = indx+1, len(nums)-1
            
            while l < r:
                t = n + nums[l] + nums[r]
                if t > 0:
                    l += 1
                elif t < 0:
                    r -= 1
                else:
                    res.append([n,nums[l],nums[r]])
                    l += 1
                    r -= 1
                    while l < r and nums[l] == nums[l-1]:
                        l += 1
        return res

Solution().threeSum([0,0,0])
# Out:
# [[0, 0, 0]]

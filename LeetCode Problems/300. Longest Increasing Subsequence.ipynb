# %% [markdown]
# 300. Longest Increasing Subsequence
#
# Given an integer array nums, return the length of the longest strictly increasing subsequence.
#
#
#
# Example 1:
#
# Input: nums = [10,9,2,5,3,7,101,18]
# Output: 4
# Explanation: The longest increasing subsequence is [2,3,7,101], therefore the length is 4.
# Example 2:
#
# Input: nums = [0,1,0,3,2,3]
# Output: 4
# Example 3:
#
# Input: nums = [7,7,7,7,7,7,7]
# Output: 1

# %%
#brute force # this not skips the big njumber obstacle and stucks at largest number
nums = [0,1,0,3,2,3]
ans = 0
for i in range(len(nums)):
    tmp = 1
    tmp_list = [nums[i]]
    prev = nums[i]
    for j in range(i+1,len(nums)):
        if nums[j] > prev:
            prev = nums[j]
            tmp += 1
            tmp_list.append(nums[j])
   
    print(tmp_list[::-1])
    ans = max(ans,tmp)
ans
# Out:
# [3, 1, 0]
# [3, 1]
# [3, 0]
# [3]
# [3, 2]
# [3]
# 3

# %%
#dp method : top down
nums = [0,1,0,3,2,3]
dp = [1]*len(nums)

for i in range(1,len(nums)):
    for j in range(i):
        if nums[j]< nums[i]:
            dp[i] = max(dp[j]+1,dp[i])

if dp:
    print(nums)
    print(dp) 
    print(max(dp))
# Out:
# [0, 1, 0, 3, 2, 3]
# [1, 2, 1, 3, 3, 4]
# 4

# %%
#LC runtime 2202ms
"""
we will build a dp table of 1's representing initially the each subsequence of 1
before iteratively checking checking dp = [1]*len(nums)

for i in range(len(nums)):
            for j in range(i):
iterating from 1 to len(n)-1 index in nums, we start with 1, because lets assume the 
initial index will have no prior subsequence and min length of subsequence is 1

for j in range(i):
    if nums[j] < nums[i]:
        dp[i] = max(dp[j]+1,dp[i])
in the j iteration loop we check if the nums[j] < nums[i], if it is less then we
greedly check if adding curr length of 1 with dp[j], if dp[j]+1 > dp[i] and we will pick the
dp value with longest length. dp[i] = max(dp[j]+1,dp[i])


"""
class Solution(object):
    def lengthOfLIS(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        dp = [1]*len(nums)
        for i in range(len(nums)):
            for j in range(i):
                if nums[j] < nums[i]:
                    dp[i] = max(dp[j]+1,dp[i])
        print(dp)
        return max(dp) if dp else 0

Solution().lengthOfLIS([10,9,2,5,3,7,101,18])
# Out:
# [1, 1, 1, 2, 2, 3, 4, 4]
# 4

# %%
#LC runtime 20 ms run time
class Solution(object):
    def lengthOfLIS(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        # n = len(nums)
        # dp = [1] * n
        
        # for i in range(1, len(nums)):
        #     for j in range(i):
        #         if nums[i]>nums[j]:
        #             dp[i] = max(dp[i], dp[j]+1)
        # return max(dp)
        sub = []
        for num in nums:
            i= bisect_left(sub, num)
            if i ==len(sub):
                sub.append(num)
            else:
                sub[i] = num
        return len(sub)
